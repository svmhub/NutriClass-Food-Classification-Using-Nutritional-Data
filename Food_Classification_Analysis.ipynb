# %% [markdown]
# ## Preparation of Python package

# %%
# !python --version
# Out:
# Python 3.10.5

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         3.0.1
# colorama          0.4.6
# comm              0.2.3
# contourpy         1.3.2
# cycler            0.12.1
# debugpy           1.8.19
# decorator         5.2.1
# exceptiongroup    1.3.1
# executing         2.2.1
# fonttools         4.61.1
# ipykernel         7.1.0
# ipython           8.38.0
# jedi              0.19.2
# joblib            1.5.3
# jupyter_client    8.8.0
# jupyter_core      5.9.1
# kiwisolver        1.4.9
# matplotlib        3.10.8
# matplotlib-inline 0.2.1
# nest-asyncio      1.6.0
# numpy             2.2.6
# packaging         25.0
# pandas            2.3.3
# parso             0.8.5
# pillow            12.1.0
# pip               25.3
# platformdirs      4.5.1
# prompt_toolkit    3.0.52
# psutil            7.2.1
# pure_eval         0.2.3
# Pygments          2.19.2
# pyparsing         3.3.1
# python-dateutil   2.9.0.post0
# pytz              2025.2
# pyzmq             27.1.0
# ...

# %%
# pip install pandas numpy matplotlib seaborn scikit-learn xgboost

# %% [markdown]
# ### 1. Importing the required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Loading the Dataset

# %%
df = pd.read_csv('synthetic_food_dataset_imbalanced.csv')

# %%
df
# Out:
#          Calories    Protein        Fat      Carbs      Sugar     Fiber  \
# 0      290.463673  14.340084  14.152608  35.266644   4.828030  1.291432
# 1      212.626748   4.080908  11.621584  23.218957  16.347814  0.130303
# 2      330.695408  14.326708  19.747680  29.479164   6.251137  0.794477
# 3      198.070798   9.452445   5.475896  32.097878   2.984621  1.710468
# 4      274.496228   6.099547  16.256002  29.756638  17.352958  1.465676
# ...           ...        ...        ...        ...        ...       ...
# 31695  103.937793   1.251053   0.452045  27.891970  14.836599  1.835365
# 31696  246.063812  10.269973  13.106895  36.416636   5.684908  1.571570
# 31697  299.997105  12.431992  11.512833  33.808189   5.737315  2.901049
# 31698  352.146284   9.170255   8.340631  39.261887   1.731604  0.027763
# 31699  203.952826   5.322650  13.419346  26.686660  14.645211  0.295026
#
#            Sodium  Cholesterol  Glycemic_Index  Water_Content  Serving_Size  \
# ...

# %% [markdown]
# ### 3. Basic analysis from the Dataset

# %%
df.shape
# Out:
# (31700, 16)

# %%
df.describe()
# Out:
#            Calories       Protein           Fat         Carbs         Sugar  \
# count  31325.000000  31325.000000  31325.000000  31325.000000  31325.000000
# mean     273.378441      9.523802     12.476848     28.943200      8.543813
# std      111.457160      8.024212      8.425834     12.668795      7.989075
# min       60.786204      0.000000      0.000000      0.000000      0.000000
# 25%      210.301731      3.858307      8.245636     25.098800      3.739656
# 50%      281.774249      9.091637     11.574161     29.681430      5.500479
# 75%      329.821946     12.683957     15.818611     34.635789     14.426303
# max     1289.956763     81.761772     88.619611    140.585537     78.548162
#
#               Fiber        Sodium   Cholesterol  Glycemic_Index  \
# count  31325.000000  31325.000000  31325.000000    31325.000000
# mean       1.904044    335.387611     26.865167       64.213509
# std        1.779542    319.066106     24.965067       25.390239
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31700 entries, 0 to 31699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Calories            31325 non-null  float64
#  1   Protein             31325 non-null  float64
#  2   Fat                 31325 non-null  float64
#  3   Carbs               31325 non-null  float64
#  4   Sugar               31325 non-null  float64
#  5   Fiber               31325 non-null  float64
#  6   Sodium              31325 non-null  float64
#  7   Cholesterol         31325 non-null  float64
#  8   Glycemic_Index      31325 non-null  float64
#  9   Water_Content       31325 non-null  float64
#  10  Serving_Size        31325 non-null  float64
#  11  Meal_Type           31700 non-null  object
#  12  Preparation_Method  31700 non-null  object
#  13  Is_Vegan            31700 non-null  bool
#  14  Is_Gluten_Free      31700 non-null  bool
# ...

# %% [markdown]
# ### 4. Finding the missing values

# %%
df.isna().sum()
# Out:
# Calories              375
# Protein               375
# Fat                   375
# Carbs                 375
# Sugar                 375
# Fiber                 375
# Sodium                375
# Cholesterol           375
# Glycemic_Index        375
# Water_Content         375
# Serving_Size          375
# Meal_Type               0
# Preparation_Method      0
# Is_Vegan                0
# Is_Gluten_Free          0
# Food_Name               0
# dtype: int64

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31325 entries, 0 to 31699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Calories            31325 non-null  float64
#  1   Protein             31325 non-null  float64
#  2   Fat                 31325 non-null  float64
#  3   Carbs               31325 non-null  float64
#  4   Sugar               31325 non-null  float64
#  5   Fiber               31325 non-null  float64
#  6   Sodium              31325 non-null  float64
#  7   Cholesterol         31325 non-null  float64
#  8   Glycemic_Index      31325 non-null  float64
#  9   Water_Content       31325 non-null  float64
#  10  Serving_Size        31325 non-null  float64
#  11  Meal_Type           31325 non-null  object
#  12  Preparation_Method  31325 non-null  object
#  13  Is_Vegan            31325 non-null  bool
#  14  Is_Gluten_Free      31325 non-null  bool
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    31260
# True        65
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31260 entries, 0 to 31699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Calories            31260 non-null  float64
#  1   Protein             31260 non-null  float64
#  2   Fat                 31260 non-null  float64
#  3   Carbs               31260 non-null  float64
#  4   Sugar               31260 non-null  float64
#  5   Fiber               31260 non-null  float64
#  6   Sodium              31260 non-null  float64
#  7   Cholesterol         31260 non-null  float64
#  8   Glycemic_Index      31260 non-null  float64
#  9   Water_Content       31260 non-null  float64
#  10  Serving_Size        31260 non-null  float64
#  11  Meal_Type           31260 non-null  object
#  12  Preparation_Method  31260 non-null  object
#  13  Is_Vegan            31260 non-null  bool
#  14  Is_Gluten_Free      31260 non-null  bool
# ...

# %%
df.columns
# Out:
# Index(['Calories', 'Protein', 'Fat', 'Carbs', 'Sugar', 'Fiber', 'Sodium',
#        'Cholesterol', 'Glycemic_Index', 'Water_Content', 'Serving_Size',
#        'Meal_Type', 'Preparation_Method', 'Is_Vegan', 'Is_Gluten_Free',
#        'Food_Name'],
#       dtype='object')

# %% [markdown]
# ### 5. Selecting the missing values columns

# %%
df.select_dtypes(include=['float64']).columns
# Out:
# Index(['Calories', 'Protein', 'Fat', 'Carbs', 'Sugar', 'Fiber', 'Sodium',
#        'Cholesterol', 'Glycemic_Index', 'Water_Content', 'Serving_Size'],
#       dtype='object')

# %% [markdown]
# ### 6. Finding the Minimum and Maximum values for the fill the null vaules

# %%
# min_val = df['Calories'].min()
# min_val

# %%
#max_val = df['Calories'].max()
#max_val

# %% [markdown]
# ### 7. Generating random values for fill the missing values in between min and max values to respective columns

# %%
#null_Count_Calories = df['Calories'].isna().sum()
#null_Count_Calories

# %%
#randam_Calories = np.random.uniform(min_val, max_val, null_Count_Calories)
#randam_Calories

# %%
""" numeric_cols = df.select_dtypes(include=['float64']).columns

for col in numeric_cols:
    mask = df[col].isna()
    if mask.any():
        min_val = df[col].min()
        max_val = df[col].max()
        df.loc[mask, col] = np.random.uniform(min_val, max_val, mask.sum())"""
# Out:
# " numeric_cols = df.select_dtypes(include=['float64']).columns\n\nfor col in numeric_cols:\n    mask = df[col].isna()\n    if mask.any():\n        min_val = df[col].min()\n        max_val = df[col].max()\n        df.loc[mask, col] = np.random.uniform(min_val, max_val, mask.sum())"

# %%
numeric_cols = df.select_dtypes(['float64']).columns
numeric_cols
# Out:
# Index(['Calories', 'Protein', 'Fat', 'Carbs', 'Sugar', 'Fiber', 'Sodium',
#        'Cholesterol', 'Glycemic_Index', 'Water_Content', 'Serving_Size'],
#       dtype='object')

# %%
df.select_dtypes(['float64']).corr()
# Out:
#                 Calories   Protein       Fat     Carbs     Sugar     Fiber  \
# Calories        1.000000  0.784635  0.812625  0.286410 -0.115676  0.024396
# Protein         0.784635  1.000000  0.744492  0.011047 -0.257308  0.105724
# Fat             0.812625  0.744492  1.000000  0.069413  0.050042 -0.036315
# Carbs           0.286410  0.011047  0.069413  1.000000  0.301198  0.362689
# Sugar          -0.115676 -0.257308  0.050042  0.301198  1.000000  0.210036
# Fiber           0.024396  0.105724 -0.036315  0.362689  0.210036  1.000000
# Sodium          0.551709  0.532459  0.517990  0.388061  0.006091  0.232376
# Cholesterol     0.722388  0.810652  0.831387 -0.118303  0.075092 -0.067733
# Glycemic_Index  0.274372  0.036499  0.143018  0.826922  0.343673  0.313639
# Water_Content  -0.078939  0.160067 -0.014499 -0.009857  0.302740  0.640317
# Serving_Size    0.621672  0.778001  0.464306  0.184503 -0.301470  0.302753
#
# ...

# %%
for col in numeric_cols:
    plt.figure(figsize=(14,6))
    sns.boxplot(data=df, x='Food_Name', y=col)
    plt.title(f"{col} Distribution by Food_Name")
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(14,6))
    sns.boxplot(data=df, x='Meal_Type', y=col)
    plt.title(f"{col} Distribution by Meal Type")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Consistency check with multiple features

# %%
sns.pairplot(
    df,
    vars=['Calories','Fat','Carbs','Sugar'],
    hue='Food_Name',
    corner=True
)
plt.show()

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA

#X = df[numeric_cols]
# y = df['Food_Name']

#X_scaled = StandardScaler().fit_transform(X)
#pca = PCA(n_components=2)
#X_pca = pca.fit_transform(X_scaled)

#pca_df = pd.DataFrame({
#    'PC1': X_pca[:,0],
#    'PC2': X_pca[:,1],
#    'Food_Name': y
#})

#plt.figure(figsize=(10,7))
#sns.scatterplot(
#    data=pca_df,
#    x='PC1', y='PC2',
#    hue='Food_Name',
#    alpha=0.6
#)
#plt.title("PCA Projection Colored by Food_Name")
#plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31260 entries, 0 to 31699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Calories            31260 non-null  float64
#  1   Protein             31260 non-null  float64
#  2   Fat                 31260 non-null  float64
#  3   Carbs               31260 non-null  float64
#  4   Sugar               31260 non-null  float64
#  5   Fiber               31260 non-null  float64
#  6   Sodium              31260 non-null  float64
#  7   Cholesterol         31260 non-null  float64
#  8   Glycemic_Index      31260 non-null  float64
#  9   Water_Content       31260 non-null  float64
#  10  Serving_Size        31260 non-null  float64
#  11  Meal_Type           31260 non-null  object
#  12  Preparation_Method  31260 non-null  object
#  13  Is_Vegan            31260 non-null  bool
#  14  Is_Gluten_Free      31260 non-null  bool
# ...

# %% [markdown]
# ### 8. Dataset is ready now!
# --- Time to start the analysis---

# %%
sns.boxplot(df)
plt.show()

# %%
for col in df.select_dtypes(include=['float64']).columns:
    plt.figure(figsize=(8, 2))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
for col in df.select_dtypes(include=['float64']).columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_fence = Q1 - 1.5 * IQR
    upper_fence = Q3 + 1.5 * IQR
    
    outliers = df[(df[col] < lower_fence) | (df[col] > upper_fence)]
outliers.shape
# Out:
# (84, 16)

# %% [markdown]
# ### Plotting the outliers

# %%
for col in outliers.select_dtypes(include=['float64']).columns:
    plt.figure(figsize=(8, 2))
    sns.boxplot(x=outliers[col])
    plt.title(col)
    plt.show()

# %%
df.shape
# Out:
# (31260, 16)

# %% [markdown]
# # Project: Food Classification Using Nutritional Data

# %% [markdown]
# ### 1. Importing the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.decomposition import PCA

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %% [markdown]
# ### 2. Data Loading

# %%
df = pd.read_csv("synthetic_food_dataset_imbalanced.csv")

# %% [markdown]
# ### 3. Basic Exploration

# %%
df.head()
# Out:
#      Calories    Protein        Fat      Carbs      Sugar     Fiber  \
# 0  290.463673  14.340084  14.152608  35.266644   4.828030  1.291432
# 1  212.626748   4.080908  11.621584  23.218957  16.347814  0.130303
# 2  330.695408  14.326708  19.747680  29.479164   6.251137  0.794477
# 3  198.070798   9.452445   5.475896  32.097878   2.984621  1.710468
# 4  274.496228   6.099547  16.256002  29.756638  17.352958  1.465676
#
#        Sodium  Cholesterol  Glycemic_Index  Water_Content  Serving_Size  \
# 0  647.553389    24.990309       81.575896      45.669118    197.570043
# 1   68.572414    34.301652       69.522492      49.854415    103.833510
# 2  663.171859    34.816834       62.552384      40.132866    198.989367
# 3  300.749543    28.510998       68.688853      57.423461    135.714202
# 4  296.314958    15.403173       70.385059      33.170460     73.019474
#
#   Meal_Type Preparation_Method  Is_Vegan  Is_Gluten_Free  Food_Name
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31700 entries, 0 to 31699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Calories            31325 non-null  float64
#  1   Protein             31325 non-null  float64
#  2   Fat                 31325 non-null  float64
#  3   Carbs               31325 non-null  float64
#  4   Sugar               31325 non-null  float64
#  5   Fiber               31325 non-null  float64
#  6   Sodium              31325 non-null  float64
#  7   Cholesterol         31325 non-null  float64
#  8   Glycemic_Index      31325 non-null  float64
#  9   Water_Content       31325 non-null  float64
#  10  Serving_Size        31325 non-null  float64
#  11  Meal_Type           31700 non-null  object
#  12  Preparation_Method  31700 non-null  object
#  13  Is_Vegan            31700 non-null  bool
#  14  Is_Gluten_Free      31700 non-null  bool
# ...

# %% [markdown]
# ### 4. Class Distribution

# %%
print(df['Meal_Type'].value_counts())
# Out:
# Meal_Type
# snack        8001
# breakfast    7970
# dinner       7873
# lunch        7856
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Meal_Type')
plt.title("Class Distribution")
plt.show()

# %% [markdown]
# ### 5. Statistical Variance Ratio

# %%
within_var = df.groupby('Meal_Type')[numeric_cols].var().mean().mean()
between_var = df.groupby('Meal_Type')[numeric_cols].mean().var().mean()

print("Within-class variance:", within_var)
print("Between-class variance:", between_var)

within_var = df.groupby('Food_Name')[numeric_cols].var().mean().mean()
between_var = df.groupby('Food_Name')[numeric_cols].mean().var().mean()

print("Within-class variance:", within_var)
print("Between-class variance:", between_var)
# Out:
# Within-class variance: 10814.340068451149
# Between-class variance: 2.56383277425109
# Within-class variance: 3533.697513074907
# Between-class variance: 7585.914171262332

# %% [markdown]
# ### 6. Data Preprocessing

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (31387, 16)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (31260, 16)

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
numeric_cols
# Out:
# Index(['Calories', 'Protein', 'Fat', 'Carbs', 'Sugar', 'Fiber', 'Sodium',
#        'Cholesterol', 'Glycemic_Index', 'Water_Content', 'Serving_Size'],
#       dtype='object')

# %%
df = df.drop(columns=['Meal_Type','Preparation_Method', 'Is_Vegan', 'Is_Gluten_Free'])

# %%
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col] = np.clip(df[col], lower, upper)

# %%
df.shape
# Out:
# (31260, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31260 entries, 0 to 31699
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Calories        31260 non-null  float64
#  1   Protein         31260 non-null  float64
#  2   Fat             31260 non-null  float64
#  3   Carbs           31260 non-null  float64
#  4   Sugar           31260 non-null  float64
#  5   Fiber           31260 non-null  float64
#  6   Sodium          31260 non-null  float64
#  7   Cholesterol     31260 non-null  float64
#  8   Glycemic_Index  31260 non-null  float64
#  9   Water_Content   31260 non-null  float64
#  10  Serving_Size    31260 non-null  float64
#  11  Food_Name       31260 non-null  object
# dtypes: float64(11), object(1)
# memory usage: 3.1+ MB

# %% [markdown]
# ### 7. Encode the target labels

# %%
# df['Meal_Type'] = df['Meal_Type'].astype('category')

# %%
# df['Meal_Type_Code'] = df['Meal_Type'].cat.codes

# %%
df.head()
# Out:
#      Calories    Protein        Fat      Carbs      Sugar     Fiber  \
# 0  290.463673  14.340084  14.152608  35.266644   4.828030  1.291432
# 1  212.626748   4.080908  11.621584  23.218957  16.347814  0.130303
# 2  330.695408  14.326708  19.747680  29.479164   6.251137  0.794477
# 3  198.070798   9.452445   5.475896  32.097878   2.984621  1.710468
# 4  274.496228   6.099547  16.256002  29.756638  17.352958  1.465676
#
#        Sodium  Cholesterol  Glycemic_Index  Water_Content  Serving_Size  \
# 0  647.553389    24.990309       81.575896      45.669118    197.570043
# 1   68.572414    34.301652       69.522492      49.854415    103.833510
# 2  663.171859    34.816834       62.552384      40.132866    198.989367
# 3  300.749543    28.510998       68.688853      57.423461    135.714202
# 4  296.314958    15.403173       70.385059      33.170460     73.019474
#
#    Food_Name
# 0      Pizza
# 1  Ice Cream
# 2     Burger
# 3      Sushi
# 4      Donut

# %% [markdown]
# ### 8. Features & Labels

# %%
X = df[numeric_cols]
# cat_cols = ['Is_Vegan','Is_Gluten_Free','Meal_Type','Preparation_Method']
# X = pd.get_dummies(df.drop(columns=['Meal_Type_Code','Food_Name']), drop_first=True)
# y = df['Meal_Type_Code']

# %%
X.head()
# Out:
#      Calories    Protein        Fat      Carbs      Sugar     Fiber  \
# 0  290.463673  14.340084  14.152608  35.266644   4.828030  1.291432
# 1  212.626748   4.080908  11.621584  23.218957  16.347814  0.130303
# 2  330.695408  14.326708  19.747680  29.479164   6.251137  0.794477
# 3  198.070798   9.452445   5.475896  32.097878   2.984621  1.710468
# 4  274.496228   6.099547  16.256002  29.756638  17.352958  1.465676
#
#        Sodium  Cholesterol  Glycemic_Index  Water_Content  Serving_Size
# 0  647.553389    24.990309       81.575896      45.669118    197.570043
# 1   68.572414    34.301652       69.522492      49.854415    103.833510
# 2  663.171859    34.816834       62.552384      40.132866    198.989367
# 3  300.749543    28.510998       68.688853      57.423461    135.714202
# 4  296.314958    15.403173       70.385059      33.170460     73.019474

# %%
df['Food_Name_Code'] = df['Food_Name'].astype('category').cat.codes

# %%
df.head()
# Out:
#      Calories    Protein        Fat      Carbs      Sugar     Fiber  \
# 0  290.463673  14.340084  14.152608  35.266644   4.828030  1.291432
# 1  212.626748   4.080908  11.621584  23.218957  16.347814  0.130303
# 2  330.695408  14.326708  19.747680  29.479164   6.251137  0.794477
# 3  198.070798   9.452445   5.475896  32.097878   2.984621  1.710468
# 4  274.496228   6.099547  16.256002  29.756638  17.352958  1.465676
#
#        Sodium  Cholesterol  Glycemic_Index  Water_Content  Serving_Size  \
# 0  647.553389    24.990309       81.575896      45.669118    197.570043
# 1   68.572414    34.301652       69.522492      49.854415    103.833510
# 2  663.171859    34.816834       62.552384      40.132866    198.989367
# 3  300.749543    28.510998       68.688853      57.423461    135.714202
# 4  296.314958    15.403173       70.385059      33.170460     73.019474
#
#    Food_Name  Food_Name_Code
# 0      Pizza               6
# 1  Ice Cream               4
# 2     Burger               2
# ...

# %%
y = df['Food_Name_Code']

# %%
y.head()
# Out:
# 0    6
# 1    4
# 2    2
# 3    9
# 4    3
# Name: Food_Name_Code, dtype: int8

# %% [markdown]
# ### 9. Scale the features

# %%
X.head()
# Out:
#      Calories    Protein        Fat      Carbs      Sugar     Fiber  \
# 0  290.463673  14.340084  14.152608  35.266644   4.828030  1.291432
# 1  212.626748   4.080908  11.621584  23.218957  16.347814  0.130303
# 2  330.695408  14.326708  19.747680  29.479164   6.251137  0.794477
# 3  198.070798   9.452445   5.475896  32.097878   2.984621  1.710468
# 4  274.496228   6.099547  16.256002  29.756638  17.352958  1.465676
#
#        Sodium  Cholesterol  Glycemic_Index  Water_Content  Serving_Size
# 0  647.553389    24.990309       81.575896      45.669118    197.570043
# 1   68.572414    34.301652       69.522492      49.854415    103.833510
# 2  663.171859    34.816834       62.552384      40.132866    198.989367
# 3  300.749543    28.510998       68.688853      57.423461    135.714202
# 4  296.314958    15.403173       70.385059      33.170460     73.019474

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 2.43575864e-01,  8.34198378e-01,  3.16105262e-01, ...,
#          1.13976175e+00, -9.30822222e-02,  1.08776771e+00],
#        [-6.46338132e-01, -8.21775448e-01, -7.36922156e-02, ...,
#          2.75660591e-01,  2.45361334e-01, -1.02151792e+00],
#        [ 7.03547592e-01,  8.32039369e-01,  1.17779025e+00, ...,
#         -2.24022194e-01, -5.40770554e-01,  1.11970575e+00],
#        ...,
#        [ 3.52572135e-01,  5.26205818e-01, -9.04406292e-02, ...,
#          6.78666948e-01, -7.14755270e-01,  1.08209987e+00],
#        [ 9.48796677e-01, -2.83905589e-04, -5.78984649e-01, ...,
#          5.46425864e-01,  1.30645305e-01,  6.39602560e-02],
#        [-7.45507579e-01, -6.21340913e-01,  2.03177255e-01, ...,
#         -5.51275135e-01,  3.50627153e-01, -7.94714845e-01]],
#       shape=(31260, 11))

# %%
X_scaled.shape
# Out:
# (31260, 11)

# %%
df.shape
# Out:
# (31260, 13)

# %% [markdown]
# ### 10. Training and Testing Set splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42, stratify=y)

# %% [markdown]
# ### 11. Model Declaration

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=200),
    "Decision Tree": DecisionTreeClassifier(
        max_depth=10, 
        min_samples_split=20, 
        min_samples_leaf=10, 
        random_state=42),
    "Random Forest": RandomForestClassifier(
        n_estimators=300, 
        max_depth=12, 
        min_samples_split=15, 
        min_samples_leaf=5, 
        max_features="sqrt", 
        random_state=42, 
        n_jobs=-1),
    "KNN": KNeighborsClassifier(
        n_neighbors=45, 
        weights="uniform",
        metric="minkowski",
        p=1, 
        leaf_size=40),
    "SVM": SVC(),
    "XGBoost": XGBClassifier(
        n_estimators=300,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=1,
        reg_lambda=1,
        eval_metric="mlogloss",
        random_state=42),
    "Gradient Boosting": GradientBoostingClassifier()
}

results = {}

# %% [markdown]
# ### 12. Model Training with confusion matix

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    results[name] = acc

    print("====================================================")
    print(f"MODEL: {name}")
    print(f"Accuracy: {acc:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix: {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()
# Out:
# ...
# MODEL: Logistic Regression
# Accuracy: 0.9945
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       368
#            1       0.98      0.99      0.99       296
#            2       0.97      1.00      0.99      1231
#            3       1.00      1.00      1.00      1113
#            4       1.00      0.99      1.00       738
#            5       1.00      1.00      1.00       990
#            6       1.00      0.99      0.99      1475
#            7       1.00      1.00      1.00       246
#            8       1.00      1.00      1.00       495
#            9       1.00      1.00      1.00       863
#
#     accuracy                           0.99      7815
#    macro avg       1.00      0.99      0.99      7815
# weighted avg       0.99      0.99      0.99      7815
# ...
# MODEL: Decision Tree
# Accuracy: 0.9869
# Classification Report:
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ### 13. Model Performance Summary

# %%
print("\nMODEL ACCURACY SUMMARY")
for name, acc in results.items():
    print(f"{name}: {acc:.4f}")
# Out:
# MODEL ACCURACY SUMMARY
# Logistic Regression: 0.9945
# Decision Tree: 0.9869
# Random Forest: 0.9936
# KNN: 0.9944
# SVM: 0.9942
# XGBoost: 0.9946
# Gradient Boosting: 0.9944

# %% [markdown]
# ### 14. Visualization the models

# %%
plt.figure(figsize=(10,4))
sns.barplot(x=list(results.keys()), y=list(results.values()))
plt.xticks(rotation=45)
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.show()

# %% [markdown]
# ### 15. Model Fitting Analysis

# %%
for name, model in models.items():
    model.fit(X_train, y_train)

    # Predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Accuracies
    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)

    results[name] = {
        "Train Accuracy": train_acc,
        "Test Accuracy": test_acc,
        "Gap": train_acc - test_acc
    }

    print(f"{name}")
    print(f"Train Accuracy : {train_acc:.4f}")
    print(f"Test Accuracy  : {test_acc:.4f}")
    print(f"Gap            : {train_acc - test_acc:.4f}")
    print("-" * 50)
# Out:
# Logistic Regression
# Train Accuracy : 0.9950
# Test Accuracy  : 0.9945
# Gap            : 0.0005
# --------------------------------------------------
# Decision Tree
# Train Accuracy : 0.9922
# Test Accuracy  : 0.9869
# Gap            : 0.0052
# --------------------------------------------------
# Random Forest
# Train Accuracy : 0.9965
# Test Accuracy  : 0.9936
# Gap            : 0.0029
# --------------------------------------------------
# KNN
# Train Accuracy : 0.9950
# Test Accuracy  : 0.9944
# Gap            : 0.0006
# --------------------------------------------------
# SVM
# Train Accuracy : 0.9963
# Test Accuracy  : 0.9942
# Gap            : 0.0020
# --------------------------------------------------
# XGBoost
# Train Accuracy : 0.9978
# Test Accuracy  : 0.9946
# Gap            : 0.0032
# --------------------------------------------------
# Gradient Boosting
# Train Accuracy : 0.9978
# Test Accuracy  : 0.9944
# Gap            : 0.0034
# ...

# %% [markdown]
# ### Interpretation Rule

# %% [markdown]
# If train_acc < 0.60 and test_acc < 0.60
#  → Underfitting
#
# If train_acc > 0.85 and gap > 0.10
# → Overfitting
#
# If gap < 0.05
# → Well generalized

# %% [markdown]
# ### 16. Visualizes the Overfitting

# %%
results_df = pd.DataFrame(results).T

results_df[['Train Accuracy','Test Accuracy']].plot(
    kind='bar', figsize=(10,5)
)

plt.title("Train vs Test Accuracy Comparison")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 17. Learning Curves(Advanced & Strong Proof)

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(model, X, y, title):
    train_sizes, train_scores, test_scores = learning_curve(
        model, X, y, cv=5, scoring='accuracy',
        train_sizes=np.linspace(0.1, 1.0, 5)
    )

    plt.plot(train_sizes, train_scores.mean(axis=1), label='Training')
    plt.plot(train_sizes, test_scores.mean(axis=1), label='Validation')
    plt.title(title)
    plt.xlabel("Training Size")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

# %%
for name, model in models.items():
    plot_learning_curve(
        model, 
        X_train, y_train, 
        name
)

# %% [markdown]
# ### 18. Saving all the Models

# %%
import joblib

joblib.dump(scaler, "scaler.pkl")

for name, model in models.items():
    joblib.dump(model, f"{name.replace(' ','_')}.pkl")

# %% [markdown]
# # Hence, all the Machine Learning models has been builded, evaluated, and tested successfully!
